# %%
from herbie import Herbie, FastHerbie
import pandas as pd, numpy as np
import xarray as xr
import dask
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import cartopy.crs as ccrs, cartopy.feature as cfeature
import requests
import pandas as pd
import io
import matplotlib.colors as mcolors

# %%
# Out:
# sh: 1: getfattr: not found
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 path = f"/home/bds5658/meteo473/sp26_groupwork/473_sp26_group9/data/{fname}.nc"
#       3 gamedata = xr.open_dataset(path)
# ----> 4 forecastplots(gamedata, 200)
#       5 indexplot(gamedata, 200)
#
# NameError: name 'forecastplots' is not defined
